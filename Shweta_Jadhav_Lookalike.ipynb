# %%
import pandas as pd

# %% [markdown]
# ### Load datasets

# %%
customers = pd.read_csv("Customers.csv")
transactions = pd.read_csv("Transactions.csv")

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Prepare data for similarity calculation

# %%
customer_profiles = transactions.groupby('CustomerID').agg(
    TotalSpent=('TotalValue', 'sum'),
    TotalQuantity=('Quantity', 'sum'),
    NumTransactions=('TransactionID', 'count')
).reset_index()

customer_profiles
# Out:
#     CustomerID  TotalSpent  TotalQuantity  NumTransactions
# 0        C0001     3354.52             12                5
# 1        C0002     1862.74             10                4
# 2        C0003     2725.38             14                4
# 3        C0004     5354.88             23                8
# 4        C0005     2034.24              7                3
# ..         ...         ...            ...              ...
# 194      C0196     4982.88             12                4
# 195      C0197     1928.65              9                3
# 196      C0198      931.83              3                2
# 197      C0199     1979.28              9                4
# 198      C0200     4758.60             16                5
#
# [199 rows x 4 columns]

# %% [markdown]
# ### Merge with customer demographics

# %%
customer_profiles = customer_profiles.merge(customers, on="CustomerID", how="left")

customer_profiles
# Out:
#     CustomerID  TotalSpent  TotalQuantity  NumTransactions  \
# 0        C0001     3354.52             12                5
# 1        C0002     1862.74             10                4
# 2        C0003     2725.38             14                4
# 3        C0004     5354.88             23                8
# 4        C0005     2034.24              7                3
# ..         ...         ...            ...              ...
# 194      C0196     4982.88             12                4
# 195      C0197     1928.65              9                3
# 196      C0198      931.83              3                2
# 197      C0199     1979.28              9                4
# 198      C0200     4758.60             16                5
#
#            CustomerName         Region  SignupDate
# 0      Lawrence Carroll  South America  2022-07-10
# 1        Elizabeth Lutz           Asia  2022-02-13
# 2        Michael Rivera  South America  2024-03-07
# 3    Kathleen Rodriguez  South America  2022-10-09
# 4           Laura Weber           Asia  2022-08-15
# ..                  ...            ...         ...
# 194         Laura Watts         Europe  2022-06-07
# 195    Christina Harvey         Europe  2023-03-21
# 196         Rebecca Ray         Europe  2022-02-27
# 197      Andrea Jenkins         Europe  2022-12-03
# 198         Kelly Cross           Asia  2023-06-11
#
# [199 rows x 7 columns]

# %% [markdown]
# ### One-hot encode categorical data

# %%
customer_profiles = pd.get_dummies(customer_profiles, columns=["Region"], drop_first=True)
customer_profiles
# Out:
#     CustomerID  TotalSpent  TotalQuantity  NumTransactions  \
# 0        C0001     3354.52             12                5
# 1        C0002     1862.74             10                4
# 2        C0003     2725.38             14                4
# 3        C0004     5354.88             23                8
# 4        C0005     2034.24              7                3
# ..         ...         ...            ...              ...
# 194      C0196     4982.88             12                4
# 195      C0197     1928.65              9                3
# 196      C0198      931.83              3                2
# 197      C0199     1979.28              9                4
# 198      C0200     4758.60             16                5
#
#            CustomerName  SignupDate  Region_Europe  Region_North America  \
# 0      Lawrence Carroll  2022-07-10          False                 False
# 1        Elizabeth Lutz  2022-02-13          False                 False
# 2        Michael Rivera  2024-03-07          False                 False
# 3    Kathleen Rodriguez  2022-10-09          False                 False
# 4           Laura Weber  2022-08-15          False                 False
# ..                  ...         ...            ...                   ...
# 194         Laura Watts  2022-06-07           True                 False
# 195    Christina Harvey  2023-03-21           True                 False
# 196         Rebecca Ray  2022-02-27           True                 False
# 197      Andrea Jenkins  2022-12-03           True                 False
# 198         Kelly Cross  2023-06-11          False                 False
#
#      Region_South America
# 0                    True
# 1                   False
# 2                    True
# 3                    True
# 4                   False
# ..                    ...
# 194                 False
# 195                 False
# 196                 False
# 197                 False
# 198                 False
#
# [199 rows x 9 columns]

# %% [markdown]
# ### Scale the data

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(customer_profiles.drop(columns=['CustomerID', 'CustomerName', 'SignupDate']))

scaled_data
# Out:
# array([[-0.06170143, -0.12203296, -0.01145819, -0.57928445, -0.54831888,
#          1.54041597],
#        [-0.87774353, -0.44800021, -0.46749414, -0.57928445, -0.54831888,
#         -0.6491753 ],
#        [-0.40585722,  0.20393428, -0.46749414, -0.57928445, -0.54831888,
#          1.54041597],
#        ...,
#        [-1.38697529, -1.58888557, -1.37956603,  1.72626765, -0.54831888,
#         -0.6491753 ],
#        [-0.81399315, -0.61098383, -0.46749414,  1.72626765, -0.54831888,
#         -0.6491753 ],
#        [ 0.70636652,  0.52990153, -0.01145819, -0.57928445, -0.54831888,
#         -0.6491753 ]])

# %% [markdown]
# ### Calculate similarity scores

# %%
similarity_matrix = cosine_similarity(scaled_data)
similarity_df = pd.DataFrame(similarity_matrix, index=customer_profiles['CustomerID'], columns=customer_profiles['CustomerID'])

similarity_df
# Out:
# CustomerID     C0001     C0002     C0003     C0004     C0005     C0006  \
# CustomerID
# C0001       1.000000 -0.095680  0.934891  0.530890 -0.059342  0.934017
# C0002      -0.095680  1.000000  0.043071 -0.599698  0.939178 -0.164442
# C0003       0.934891  0.043071  1.000000  0.419987  0.057060  0.885906
# C0004       0.530890 -0.599698  0.419987  1.000000 -0.733285  0.476839
# C0005      -0.059342  0.939178  0.057060 -0.733285  1.000000 -0.042154
# ...              ...       ...       ...       ...       ...       ...
# C0196      -0.462467 -0.227224 -0.462354 -0.265022 -0.096249 -0.282143
# C0197      -0.378155  0.327699 -0.238794 -0.691169  0.412649 -0.351680
# C0198      -0.254480  0.483087 -0.138796 -0.818464  0.610718 -0.245283
# C0199      -0.405059  0.278300 -0.309054 -0.638543  0.332219 -0.424052
# C0200      -0.200057  0.101177 -0.213791  0.308848  0.007199 -0.051621
#
# CustomerID     C0007     C0008     C0009     C0010  ...     C0191     C0192  \
# CustomerID                                          ...
# C0001      -0.079354 -0.325263 -0.268882 -0.422674  ...  0.989767  0.863789
# C0002       0.910784 -0.450039  0.465470  0.253011  ... -0.002019  0.276753
# C0003       0.034904 -0.436800 -0.183052 -0.273710  ...  0.929618  0.868546
# C0004      -0.697686  0.395848 -0.794886 -0.542460  ...  0.429617  0.047458
# C0005       0.986855 -0.624653  0.570299  0.250664  ...  0.035126  0.359170
# ...              ...       ...       ...       ...  ...       ...       ...
# C0196      -0.043289 -0.341975  0.488635  0.663441  ... -0.490083 -0.447185
# C0197       0.370256 -0.610289  0.939020  0.958796  ... -0.307852 -0.030614
# C0198       0.551865 -0.689978  0.990445  0.840272  ... -0.155255  0.185269
# C0199       0.277027 -0.507880  0.932712  0.973591  ... -0.331416 -0.082775
# C0200       0.140329  0.149817 -0.515409 -0.339383  ... -0.289012 -0.459350
#
# CustomerID     C0193     C0194     C0195     C0196     C0197     C0198  \
# CustomerID
# C0001      -0.148611 -0.441002  0.856848 -0.462467 -0.378155 -0.254480
# C0002       0.908916 -0.283360 -0.396157 -0.227224  0.327699  0.483087
# C0003      -0.046034 -0.515606  0.781295 -0.462354 -0.238794 -0.138796
# C0004      -0.492785  0.018990  0.887004 -0.265022 -0.691169 -0.818464
# C0005       0.888309 -0.349205 -0.464716 -0.096249  0.412649  0.610718
# ...              ...       ...       ...       ...       ...       ...
# C0196      -0.090663 -0.383794 -0.414536  1.000000  0.687718  0.497414
# C0197       0.190450 -0.513159 -0.605264  0.687718  1.000000  0.945064
# C0198       0.308943 -0.487371 -0.623458  0.497414  0.945064  1.000000
# C0199       0.120128 -0.463381 -0.596654  0.693650  0.982323  0.913263
# C0200       0.454979  0.003312  0.082728  0.085224 -0.368401 -0.484813
#
# CustomerID     C0199     C0200
# CustomerID
# C0001      -0.405059 -0.200057
# C0002       0.278300  0.101177
# C0003      -0.309054 -0.213791
# C0004      -0.638543  0.308848
# C0005       0.332219  0.007199
# ...              ...       ...
# C0196       0.693650  0.085224
# C0197       0.982323 -0.368401
# C0198       0.913263 -0.484813
# C0199       1.000000 -0.388117
# C0200      -0.388117  1.000000
#
# [199 rows x 199 columns]

# %% [markdown]
# ### Get top 3 similar customers for each customer

# %%
lookalikes = {}
for customer_id in customer_profiles['CustomerID']:
    similar_customers = similarity_df[customer_id].sort_values(ascending=False).iloc[1:4]
    lookalikes[customer_id] = list(similar_customers.items())

# %% [markdown]
# ### Save lookalikes to CSV

# %%
lookalikes_df = pd.DataFrame.from_dict(lookalikes, orient='index', columns=['1st Similar', '2nd Similar', '3rd Similar'])
lookalikes_df.to_csv("ShwetaJadhav_Lookalike.csv", index_label="CustomerID")

# %% [markdown]
# ### Print the lookalikes for the first 20 customers

# %%
print("Lookalike Recommendations for the first 20 customers:")
print(lookalikes_df.head(20))
# Out:
# Lookalike Recommendations for the first 20 customers:
#                        1st Similar                  2nd Similar  \
# C0001  (C0107, 0.9964160629333633)  (C0137, 0.9957000029067153)
# C0002  (C0142, 0.9887986276382208)  (C0177, 0.9665054843287145)
# C0003  (C0190, 0.9663449212719497)  (C0133, 0.9639721457875143)
# C0004  (C0113, 0.9950141093849689)  (C0102, 0.9835928774397132)
# C0005  (C0186, 0.9975070362104175)  (C0159, 0.9969876736870633)
# C0006  (C0168, 0.9754290315127764)  (C0048, 0.9627599759935872)
# C0007   (C0159, 0.988544915655898)  (C0005, 0.9868551577843031)
# C0008   (C0109, 0.925172862452882)  (C0068, 0.9152451511526559)
# C0009  (C0198, 0.9904450554756707)  (C0063, 0.9786381398416024)
# C0010  (C0166, 0.9832367748277806)   (C0199, 0.973590895201623)
# C0011   (C0107, 0.995063364744912)  (C0048, 0.9949454856521013)
# C0012  (C0155, 0.9905466186001887)  (C0013, 0.9849235776725346)
# C0013  (C0155, 0.9921034257097614)  (C0012, 0.9849235776725346)
# C0014   (C0060, 0.999523553415881)  (C0198, 0.9936908605687136)
# C0015  (C0020, 0.9940224184241141)  (C0058, 0.9905026619175442)
# C0016  (C0183, 0.9876948737242969)  (C0154, 0.9720909301428636)
# C0017  (C0124, 0.9834717633265204)  (C0075, 0.9649498752234789)
# C0018  (C0046, 0.9268806452565849)  (C0122, 0.9253294504794928)
# C0019   (C0172, 0.997127283699905)  (C0127, 0.9627816225194765)
# C0020  (C0058, 0.9957496926049496)  (C0033, 0.9945305653099178)
#
#                        3rd Similar
# C0001  (C0191, 0.9897669426714507)
# C0002  (C0186, 0.9513671519805773)
# C0003  (C0174, 0.9518828279691799)
# C0004  (C0165, 0.9762195619743639)
# C0005  (C0140, 0.9869414640620454)
# C0006  (C0187, 0.9596221458824508)
# C0007  (C0115, 0.9831446127812815)
# C0008  (C0098, 0.9098767953777047)
# C0009  (C0014, 0.9731452838370526)
# C0010   (C0073, 0.966885950622985)
# C0011  (C0001, 0.9886540744006409)
# C0012  (C0102, 0.9827303982506488)
# C0013  (C0104, 0.9842353831377147)
# C0014  (C0063, 0.9863828136925823)
# C0015  (C0033, 0.9894484548020199)
# C0016  (C0117, 0.9632924632100219)
# C0017  (C0041, 0.9522815902370341)
# C0018  (C0067, 0.9244769335596386)
# C0019  (C0069, 0.9568419623145136)
# C0020  (C0015, 0.9940224184241141)

# %% [markdown]
# * Customer C0001 is most similar to C0107, C0137, and C0191 based on their spending habits and profiles. These recommendations can be used for:
# * Suggesting similar products that these customers are likely to purchase.
# * Targeting them with similar promotional offers.
